# %%
import pandas as pd

# %%
#pip install git+https://github.com/quantopian/pyfolio
# import again if first time not work
import pyfolio
# Out:
# c:\Users\isobr\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline

# %%
def get_daily_return(df):
    df['daily_return']=df.account_value.pct_change(1)
    #df=df.dropna()
    print('Sharpe: ',(252**0.5)*df['daily_return'].mean()/ df['daily_return'].std())
    return df

# %%
def backtest_strat(df):
    strategy_ret= df.copy()
    strategy_ret['Date'] = pd.to_datetime(strategy_ret['Date'])
    strategy_ret.set_index('Date', drop = False, inplace = True)
    strategy_ret.index = strategy_ret.index.tz_localize('UTC')
    del strategy_ret['Date']
    ts = pd.Series(strategy_ret['daily_return'].values, index=strategy_ret.index)
    return ts

# %%
def get_account_value(model_name):
    dfs = []
    for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
        temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format(model_name,i))
        dfs.append(temp)
    df_account_value = pd.concat(dfs, ignore_index=True)
    df_account_value = pd.DataFrame({'account_value':df_account_value['0']})
    sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
    print(sharpe)
    df_account_value=df_account_value.join(df_trade_date[63:].reset_index(drop=True))
    return df_account_value

# %% [markdown]
# ## DJIA

# %%
dji = pd.read_csv("data/^DJI.csv")
test_dji=dji[(dji['Date']>='2016-01-01') & (dji['Date']<='2025-06-30')]
test_dji = test_dji.reset_index(drop=True)

# %%
test_dji.shape
# Out:
# (1166, 7)

# %%
test_dji.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-01-04  17405.480469  17405.480469  16957.630859  17148.939453
# 1  2016-01-05  17147.500000  17195.839844  17038.609375  17158.660156
# 2  2016-01-06  17154.830078  17154.830078  16817.619141  16906.509766
# 3  2016-01-07  16888.359375  16888.359375  16463.630859  16514.099609
# 4  2016-01-08  16519.169922  16651.890625  16314.570313  16346.450195
#
#       Adj Close     Volume
# 0  17148.939453  148060000
# 1  17158.660156  105750000
# 2  16906.509766  120250000
# 3  16514.099609  176240000
# 4  16346.450195  141850000

# %%
test_dji['daily_return']=test_dji['Adj Close'].pct_change(1)

# %%
dow_strat = backtest_strat(test_dji)

# %% [markdown]
# ## Ensemble Strategy

# %%
df=pd.read_csv('data/dow_30_2009_2020.csv')

# %%
rebalance_window = 63
validation_window = 63
unique_trade_date = df[(df.datadate > 20151001)&(df.datadate <= 20250707)].datadate.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

# %%
ensemble_account_value = get_account_value('ensemble')
# Out:
# 1.1148251939180702

# %%
ensemble_account_value.account_value.plot()
# Out:
# <Axes: >

# %%
ensemble_account_value = get_daily_return(ensemble_account_value)
# Out:
# Sharpe:  1.1148251939180702

# %%
ensemble_account_value['Date'] = test_dji['Date']

# %%
ensemble_account_value.head()
# Out:
#     account_value  datadate  daily_return        Date
# 0  1000000.000000  20160104           NaN  2016-01-04
# 1   999264.361649  20160105     -0.000736  2016-01-05
# 2   994398.220391  20160106     -0.004870  2016-01-06
# 3   985983.323020  20160107     -0.008462  2016-01-07
# 4   980694.335405  20160108     -0.005364  2016-01-08

# %%
ensemble_strat = backtest_strat(ensemble_account_value[0:1097])

# %%
#ensemble_account_value.to_csv('results/df_account_value_ensemble_daily_return.csv',index=False)

# %%
with pyfolio.plotting.plotting_context(font_scale=1.1):
    pyfolio.create_full_tear_sheet(returns = ensemble_strat,
                                   benchmark_rets=dow_strat, set_context=False)
# Out:
# c:\Users\isobr\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.86%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-05-12</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>52</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>9.86%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>50.587%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.696%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.13</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.45</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-6.819%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.30</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.66</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.057%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.09</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6.82</td>
#       <td>2016-01-04</td>
#       <td>2016-02-11</td>
#       <td>2016-03-01</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.34</td>
#       <td>2016-04-27</td>
#       <td>2016-06-27</td>
#       <td>2016-07-12</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.64</td>
#       <td>2016-08-15</td>
#       <td>2016-11-04</td>
#       <td>2016-11-10</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.13</td>
#       <td>2018-06-11</td>
#       <td>2018-06-27</td>
#       <td>2019-01-17</td>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.12</td>
#       <td>2019-04-01</td>
#       <td>2020-03-02</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# c:\Users\isobr\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\dates.py:449: UserWarning: no explicit representation of timezones available for np.datetime64
#   d = d.astype('datetime64[us]')
# c:\Users\isobr\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyfolio\plotting.py:1407: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Daily", "Weekly", "Monthly"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.06%</td>
#       <td>-3.59%</td>
#       <td>2.43%</td>
#     </tr>
#     <tr>
#       <th>Covid</th>
#       <td>-0.02%</td>
#       <td>-0.87%</td>
#       <td>0.10%</td>
#     </tr>
#   </tbody>
# </table>
